# %%
item_price = 250
delivery_fee = 30
coupon_discount = 20

print("Item price: ",item_price)
print("Delivery charges:",delivery_fee)
print("Coupon discount: ",coupon_discount)
# Out:
# Item price:  250
# Delivery charges: 30
# Coupon discount:  20

# %%
product_price = int(input("Eneter the product price = "))
if product_price > 1000:
    print("Free delivery")
else: 
    print("Delivery chares will be applyed")
# Out:
# Eneter the product price =  500
# Delivery chares will be applyed

# %%
team_name = "Mumbai Indians"
runs_scored = 180
overs_played = 20

print("Team Name:", team_name)
print("Runs Scored:", runs_scored)
print("Overs Played:", overs_played)
# Out:
# Team Name: Mumbai Indians
# Runs Scored: 180
# Overs Played: 20
